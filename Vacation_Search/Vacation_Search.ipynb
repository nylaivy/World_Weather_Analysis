# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import time

# Import API key
from config import gkey

# Configure gmaps API key
gmaps.configure(api_key=gkey)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    Unnamed: 0          City Country      Lat      Lng  Max Temp  Humidity  \
# 0           0       Ushuaia      AR -54.8000 -68.3000     28.06       100
# 1           1          Selu      IN  19.4667  76.4667     95.13        34
# 2           2  Longyearbyen      SJ  78.2186  15.6401     30.04        64
# 3           3   Port Alfred      ZA -33.5906  26.8910     71.01        48
# 4           4      Hermanus      ZA -34.4187  19.2345     68.81        77
#
#    Cloudiness  Wind Speed Current Description
# 0          75       24.16          light snow
# 1         100       14.79       moderate rain
# 2          40        5.75    scattered clouds
# 3          64       20.85       broken clouds
# 4          16       22.10          few clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     Unnamed: 0             City Country      Lat       Lng  Max Temp  \
# 13          13         Victoria      HK  22.2855  114.1577     89.33
# 15          15   Saint-Philippe      RE -21.3585   55.7679     78.39
# 16          16     Oktyabrskoye      RU  43.0645   44.7417     78.94
# 19          19       Nouakchott      MR  18.0858  -15.9785     78.73
# 27          27           Artyom      AZ  40.4723   50.3330     75.34
# 29          29      Grand Gaube      MU -20.0064   57.6608     81.37
# 34          34        Bathsheba      BB  13.2167  -59.5167     84.81
# 37          37        Mahebourg      MU -20.4081   57.7000     81.25
# 39          39       Georgetown      MY   5.4112  100.3354     86.00
# 40          40  Bambous Virieux      MU -20.3428   57.7575     81.00
#
#     Humidity  Cloudiness  Wind Speed Current Description
# 13        85          63        5.99       broken clouds
# 15        76          40        5.01    scattered clouds
# 16        39          40        6.89    scattered clouds
# 19        58          41       14.05    scattered clouds
# 27        66          35       18.39    scattered clouds
# 29        67          23        1.99          light rain
# 34        51          20       15.73          few clouds
# 37        73          20        4.61          few clouds
# 39        84          20        6.91          few clouds
# 40        73          20        4.61          light rain

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# Unnamed: 0             288
# City                   288
# Country                285
# Lat                    288
# Lng                    288
# Max Temp               288
# Humidity               288
# Cloudiness             288
# Wind Speed             288
# Current Description    288
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.dropna()
clean_df
# Out:
#      Unnamed: 0            City Country      Lat       Lng  Max Temp  \
# 13           13        Victoria      HK  22.2855  114.1577     89.33
# 15           15  Saint-Philippe      RE -21.3585   55.7679     78.39
# 16           16    Oktyabrskoye      RU  43.0645   44.7417     78.94
# 19           19      Nouakchott      MR  18.0858  -15.9785     78.73
# 27           27          Artyom      AZ  40.4723   50.3330     75.34
# ..          ...             ...     ...      ...       ...       ...
# 688         688          Grajau      BR  -5.8194  -46.1386     83.97
# 696         696      Porto Novo      BJ   6.4965    2.6036     89.42
# 699         699            Arsk      RU  56.0915   49.8778     76.78
# 703         703       Chalmette      US  29.9427  -89.9634     80.01
# 704         704      Rameswaram      IN   9.2833   79.3000     84.34
#
#      Humidity  Cloudiness  Wind Speed Current Description
# 13         85          63        5.99       broken clouds
# 15         76          40        5.01    scattered clouds
# 16         39          40        6.89    scattered clouds
# 19         58          41       14.05    scattered clouds
# 27         66          35       18.39    scattered clouds
# ..        ...         ...         ...                 ...
# 688        54          55        3.71       broken clouds
# 696        56          70       11.01       broken clouds
# 699        46           2        7.81           clear sky
# 703        75          20        1.99          few clouds
# 704        77          60       19.82       broken clouds
#
# [285 rows x 10 columns]

# %%
clean_df.count()
# Out:
# Unnamed: 0             285
# City                   285
# Country                285
# Lat                    285
# Lng                    285
# Max Temp               285
# Humidity               285
# Cloudiness             285
# Wind Speed             285
# Current Description    285
# dtype: int64

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 13         Victoria      HK     89.33       broken clouds  22.2855  114.1577
# 15   Saint-Philippe      RE     78.39    scattered clouds -21.3585   55.7679
# 16     Oktyabrskoye      RU     78.94    scattered clouds  43.0645   44.7417
# 19       Nouakchott      MR     78.73    scattered clouds  18.0858  -15.9785
# 27           Artyom      AZ     75.34    scattered clouds  40.4723   50.3330
# 29      Grand Gaube      MU     81.37          light rain -20.0064   57.6608
# 34        Bathsheba      BB     84.81          few clouds  13.2167  -59.5167
# 37        Mahebourg      MU     81.25          few clouds -20.4081   57.7000
# 39       Georgetown      MY     86.00          few clouds   5.4112  100.3354
# 40  Bambous Virieux      MU     81.00          light rain -20.3428   57.7575
#
#    Hotel Name
# 13
# 15
# 16
# 19
# 27
# 29
# 34
# 37
# 39
# 40

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": gkey
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    time.sleep(0.5)
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna()
clean_hotel_df
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 13         Victoria      HK     89.33       broken clouds  22.2855  114.1577
# 15   Saint-Philippe      RE     78.39    scattered clouds -21.3585   55.7679
# 16     Oktyabrskoye      RU     78.94    scattered clouds  43.0645   44.7417
# 19       Nouakchott      MR     78.73    scattered clouds  18.0858  -15.9785
# 27           Artyom      AZ     75.34    scattered clouds  40.4723   50.3330
# ..              ...     ...       ...                 ...      ...       ...
# 688          Grajau      BR     83.97       broken clouds  -5.8194  -46.1386
# 696      Porto Novo      BJ     89.42       broken clouds   6.4965    2.6036
# 699            Arsk      RU     76.78           clear sky  56.0915   49.8778
# 703       Chalmette      US     80.01          few clouds  29.9427  -89.9634
# 704      Rameswaram      IN     84.34       broken clouds   9.2833   79.3000
#
#                                     Hotel Name
# 13                          Mini Hotel Central
# 15                Chambres d'hôte "La Trinité"
# 16                         Prolesok Mini-hotel
# 19                       HOTEL IMAN فندق إيمان
# 27                              Merdan Respect
# ..                                         ...
# 688                            Hotel Confiança
# 696                    Tour Eiffel Hotel Benin
# 699                        Gostinitsa Zapadnyy
# 703  Marina Inn & Suites Chalmette-New Orleans
# 704                   Daiwik Hotels Rameswaram
#
# [285 rows x 7 columns]

# %%
# 8a. Create the output File (CSV)
output_data_file = clean_hotel_df.to_csv(r'WeatherPy_vacation.csv')
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# 'City_ID,City,Country,Max Temp,Current Description,Lat,Lng,Hotel Name\n13,Victoria,HK,89.33,broken clouds,22.2855,114.1577,Mini Hotel Central\n15,Saint-Philippe,RE,78.39,scattered clouds,-21.3585,55.7679,"Chambres d\'hôte ""La Trinité"""\n16,Oktyabrskoye,RU,78.94,scattered clouds,43.0645,44.7417,Prolesok Mini-hotel\n19,Nouakchott,MR,78.73,scattered clouds,18.0858,-15.9785,HOTEL IMAN فندق إيمان\n27,Artyom,AZ,75.34,scattered clouds,40.4723,50.333,Merdan Respect\n29,Grand Gaube,MU,81.37,light rain,-20.0064,57.6608,Veranda Paul et Virginie Hotel & Spa\n34,Bathsheba,BB,84.81,few clouds,13.2167,-59.5167,Atlantis Hotel\n37,Mahebourg,MU,81.25,few clouds,-20.4081,57.7,Shandrani Beachcomber Resort & Spa\n39,Georgetown,MY,86.0,few clouds,5.4112,100.3354,Cititel Penang\n40,Bambous Virieux,MU,81.0,light rain,-20.3428,57.7575,Casa Tia Villa\n43,Dingle,PH,80.42,moderate rain,10.9995,122.6711,SEGAYA PROPERTY\n48,Calatayud,ES,81.64,overcast clouds,41.3535,-1.6432,Hotel Monasterio Benedictino\n52,Arraial Do Cabo,BR,76.96,few clouds,-22.9661,-42.0278,Pousada Porto Praia\n53,Belmonte,BR,79.3,clear sky,-15.8631,-38.8828,Pousada Monte Carmelo O Pão\n54,Inhambane,MZ,80.58,few clouds,-23.865,35.3833,Oceano\n55,Kalangala,UG,75.04,broken clouds,-0.3089,32.225,Ssese Habitat Resort\n60,Bonthe,SL,84.9,light rain,7.5264,-12.505,Bonthe Holiday Village\n61,Korla,CN,89.94,clear sky,41.7597,86.1469,Gulisitan Hotel\n63,Matiguas,NI,79.54,overcast clouds,12.8373,-85.4622,Hotel Bethel\n65,Carutapera,BR,82.08,clear sky,-1.195,-46.02,Lidera\n66,Namibe,AO,84.83,clear sky,-15.1961,12.1522,Hotel Chik Chik Namibe\n67,Cayenne,GF,80.1,overcast clouds,4.9333,-52.3333,Hôtel Le Dronmi\n68,Cabedelo,BR,81.27,broken clouds,-6.9811,-34.8339,Hotel Pigalle\n71,Dennery,LC,82.4,scattered clouds,13.8996,-60.8879,The Fox Grove Inn\n76,Feijo,BR,77.74,scattered clouds,-8.1642,-70.3536,Hotel e Restaurante Aҫai\n79,The Valley,AI,83.1,broken clouds,18.217,-63.0578,CeBlue Villas & Beach Resort\n81,Bubaque,GW,77.86,few clouds,11.2833,-15.8333,"Casa Dora, Bubaque"\n82,Thinadhoo,MV,84.9,scattered clouds,0.5333,72.9333,\n83,Kashi,CN,88.81,few clouds,39.4547,75.9797,帕米尔青年旅舍\n84,Caravelas,BR,81.9,few clouds,-17.7125,-39.2481,Pousada dos Navegantes\n86,Boa Vista,BR,76.98,broken clouds,2.8197,-60.6733,Aipana Plaza Hotel\n87,Luanda,AO,82.4,clear sky,-8.8368,13.2343,LANDU MARINEZA LUFUANDU TONI\n90,Sao Joao Da Barra,BR,75.29,clear sky,-21.6403,-41.0511,Pousada Porto De Canoas\n94,Hithadhoo,MV,82.81,overcast clouds,-0.6,73.0833,Scoop Guest House\n98,Itacoatiara,BR,81.07,broken clouds,-3.1431,-58.4442,BBB Rooms Centro Itacoatiara AM\n99,Cockburn Town,TC,78.42,overcast clouds,21.4612,-71.1419,Osprey Beach Hotel\n101,Erzurum,TR,78.8,broken clouds,40.0,41.5,\n117,Abonnema,NG,87.8,light rain,4.7084,6.7931,Corper\'s Lodge Obonoma\n118,Dangriga,BZ,82.0,scattered clouds,16.9692,-88.2321,Chaleanor Hotel\n119,Rincon,US,78.85,few clouds,32.296,-81.2354,Days Inn Rincon\n120,Arraias,BR,83.12,clear sky,-12.9288,-46.9437,Hotel Japão\n122,Axim,GH,85.05,overcast clouds,4.8699,-2.2405,AXIM BEACH RESORT AND SPA\n126,Zabol,AF,84.63,clear sky,32.25,67.25,\n127,Puri,IN,88.32,few clouds,19.8,85.85,OYO 1577 Hotel Shree Hari Grand\n128,Cap Malheureux,MU,81.0,scattered clouds,-19.9842,57.6142,Pereybere Hotel & Spa\n130,Souillac,MU,81.36,few clouds,-20.5167,57.5167,Shanti Maurice Resort & Spa\n132,Marivan,IR,87.89,clear sky,35.5219,46.176,Miran Hotel\n134,Faya,SA,86.0,clear sky,18.3851,42.4509,مقبرة ال مجمل\n138,Parrita,CR,82.17,broken clouds,9.5201,-84.3225,Beso del Viento\n139,Ios,GR,76.91,scattered clouds,36.7333,25.2833,Ios Palace Hotel & Spa\n140,Massaranduba,BR,76.59,broken clouds,-7.2003,-35.7892,\n142,Shkoder,AL,77.18,clear sky,42.0683,19.5126,Hotel Tradita\n146,Gamba,GA,82.09,overcast clouds,-2.65,10.0,\n147,Culfa,AZ,87.8,overcast clouds,38.9558,45.6308,Hotel Araz\n149,Beja,TN,86.0,broken clouds,36.7256,9.1817,باجة العتيقة Beja El Medina\n152,Quatre Cocos,MU,81.09,scattered clouds,-20.2078,57.7625,Emeraude Beach Attitu ...

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
